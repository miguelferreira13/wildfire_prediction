# %% [markdown]
# # Merging Data Sets

# %%
import pandas as pd

# %%
weather = pd.read_csv('../wildfire_prediction/data/weather.csv', index_col=0)

# %%
wildfire = pd.read_csv('../wildfire_prediction/data/wildfire_history.csv', index_col=0)

# %%
vegetation = pd.read_csv('../wildfire_prediction/data/VegetationIndex.csv', index_col=0)

# %%
landclass = pd.read_csv('../wildfire_prediction/data/Landclass.csv', index_col=0)

# %%
vegetation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1344 entries, 0 to 1343
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Region                     1344 non-null   object
#  1   Date                       1344 non-null   object
#  2   Vegetation_index_mean      1344 non-null   float64
#  3   Vegetation_index_max       1344 non-null   float64
#  4   Vegetation_index_min       1344 non-null   float64
#  5   Vegetation_index_std       1344 non-null   float64
#  6   Vegetation_index_variance  1344 non-null   float64
#  7   year                       1344 non-null   int64
#  8   month                      1344 non-null   int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 105.0+ KB

# %%
merged = weather.merge(wildfire, how='left', on = ['Year', 'Month', 'Day', 'Region'])

# %%
merged.drop(columns='Date_y', inplace=True)

# %%
merged = merged.merge(vegetation, how='left'\
                      , left_on = ['Year', 'Month', 'Region'], right_on= ['year', 'month', 'Region'])

# %%
merged.drop(columns='Date', inplace=True)

# %%
merged = merged.merge(landclass, how='left', on = ['Region'])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40971 entries, 0 to 40970
# Data columns (total 62 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Date_x                                                    40971 non-null  object
#  1   Region                                                    40971 non-null  object
#  2   count()[unit: km^2]                                       40971 non-null  float64
#  3   max() Precipitation                                       40964 non-null  float64
#  4   max() RelativeHumidity                                    40929 non-null  float64
#  5   max() SoilWaterContent                                    40971 non-null  float64
#  6   max() SolarRadiation                                      40957 non-null  float64
#  7   max() Temperature                                         40957 non-null  float64
#  8   max() WindSpeed                                           40943 non-null  float64
#  9   mean() Precipitation                                      40964 non-null  float64
#  10  mean() RelativeHumidity                                   40929 non-null  float64
#  11  mean() SoilWaterContent                                   40971 non-null  float64
#  12  mean() SolarRadiation                                     40957 non-null  float64
#  13  mean() Temperature                                        40957 non-null  float64
#  14  mean() WindSpeed                                          40943 non-null  float64
#  15  min() Precipitation                                       40964 non-null  float64
#  16  min() RelativeHumidity                                    40929 non-null  float64
#  17  min() SoilWaterContent                                    40971 non-null  float64
#  18  min() SolarRadiation                                      40957 non-null  float64
#  19  min() Temperature                                         40957 non-null  float64
#  20  min() WindSpeed                                           40943 non-null  float64
#  21  variance() Precipitation                                  40964 non-null  float64
#  22  variance() RelativeHumidity                               40929 non-null  float64
#  23  variance() SoilWaterContent                               40971 non-null  float64
#  24  variance() SolarRadiation                                 40957 non-null  float64
#  25  variance() Temperature                                    40957 non-null  float64
#  26  variance() WindSpeed                                      40943 non-null  float64
#  27  day                                                       40971 non-null  int64
#  28  month_x                                                   40971 non-null  int64
#  29  year_x                                                    40971 non-null  int64
#  30  Year                                                      40971 non-null  int64
#  31  Month                                                     40971 non-null  int64
#  32  Day                                                       40971 non-null  int64
#  33  Estimated_fire_area                                       26667 non-null  float64
#  34  Mean_estimated_fire_brightness                            26667 non-null  float64
#  35  Mean_estimated_fire_radiative_power                       26667 non-null  float64
#  36  Mean_confidence                                           26667 non-null  float64
#  37  Std_confidence                                            24432 non-null  float64
#  38  Var_confidence                                            24432 non-null  float64
#  39  Count                                                     26667 non-null  float64
#  40  Replaced                                                  26667 non-null  object
#  41  Vegetation_index_mean                                     40908 non-null  float64
#  42  Vegetation_index_max                                      40908 non-null  float64
#  43  Vegetation_index_min                                      40908 non-null  float64
#  44  Vegetation_index_std                                      40908 non-null  float64
#  45  Vegetation_index_variance                                 40908 non-null  float64
#  46  year_y                                                    40908 non-null  float64
#  47  month_y                                                   40908 non-null  float64
#  48  Shrubs                                                    40971 non-null  float64
#  49  Herbaceous vegetation                                     40971 non-null  float64
#  50  Cultivated and managed vegetation/agriculture (cropland)  40971 non-null  float64
#  51  Urban / built up                                          40971 non-null  float64
#  52  Bare / sparse vegetation                                  40971 non-null  float64
#  53  Permanent water bodies                                    40971 non-null  float64
#  54  Herbaceous wetland                                        40971 non-null  float64
#  55  Closed forest, evergreen, broad leaf                      40971 non-null  float64
#  56  Closed forest, deciduous broad leaf                       40971 non-null  float64
#  57  Closed forest, unknown                                    40971 non-null  float64
#  58  Open forest, evergreen broad leaf                         40971 non-null  float64
#  59  Open forest, deciduous broad leaf                         40971 non-null  float64
#  60  Open forest, unknown definitions                          40971 non-null  float64
#  61  Open sea                                                  40971 non-null  float64
# dtypes: float64(53), int64(6), object(3)
# memory usage: 19.7+ MB

# %%
merged.drop(columns=['month_x', 'month_y', 'year_y', 'year_x', 'day', 'Replaced', 'Count'\
                    , 'Mean_confidence', 'Std_confidence', 'Mean_confidence'\
                    , 'Vegetation_index_max', 'Vegetation_index_min', 'Vegetation_index_std'\
                    , 'Var_confidence'], inplace=True)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40971 entries, 0 to 40970
# Data columns (total 49 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Date_x                                                    40971 non-null  object
#  1   Region                                                    40971 non-null  object
#  2   count()[unit: km^2]                                       40971 non-null  float64
#  3   max() Precipitation                                       40964 non-null  float64
#  4   max() RelativeHumidity                                    40929 non-null  float64
#  5   max() SoilWaterContent                                    40971 non-null  float64
#  6   max() SolarRadiation                                      40957 non-null  float64
#  7   max() Temperature                                         40957 non-null  float64
#  8   max() WindSpeed                                           40943 non-null  float64
#  9   mean() Precipitation                                      40964 non-null  float64
#  10  mean() RelativeHumidity                                   40929 non-null  float64
#  11  mean() SoilWaterContent                                   40971 non-null  float64
#  12  mean() SolarRadiation                                     40957 non-null  float64
#  13  mean() Temperature                                        40957 non-null  float64
#  14  mean() WindSpeed                                          40943 non-null  float64
#  15  min() Precipitation                                       40964 non-null  float64
#  16  min() RelativeHumidity                                    40929 non-null  float64
#  17  min() SoilWaterContent                                    40971 non-null  float64
#  18  min() SolarRadiation                                      40957 non-null  float64
#  19  min() Temperature                                         40957 non-null  float64
#  20  min() WindSpeed                                           40943 non-null  float64
#  21  variance() Precipitation                                  40964 non-null  float64
#  22  variance() RelativeHumidity                               40929 non-null  float64
#  23  variance() SoilWaterContent                               40971 non-null  float64
#  24  variance() SolarRadiation                                 40957 non-null  float64
#  25  variance() Temperature                                    40957 non-null  float64
#  26  variance() WindSpeed                                      40943 non-null  float64
#  27  Year                                                      40971 non-null  int64
#  28  Month                                                     40971 non-null  int64
#  29  Day                                                       40971 non-null  int64
#  30  Estimated_fire_area                                       26667 non-null  float64
#  31  Mean_estimated_fire_brightness                            26667 non-null  float64
#  32  Mean_estimated_fire_radiative_power                       26667 non-null  float64
#  33  Vegetation_index_mean                                     40908 non-null  float64
#  34  Vegetation_index_variance                                 40908 non-null  float64
#  35  Shrubs                                                    40971 non-null  float64
#  36  Herbaceous vegetation                                     40971 non-null  float64
#  37  Cultivated and managed vegetation/agriculture (cropland)  40971 non-null  float64
#  38  Urban / built up                                          40971 non-null  float64
#  39  Bare / sparse vegetation                                  40971 non-null  float64
#  40  Permanent water bodies                                    40971 non-null  float64
#  41  Herbaceous wetland                                        40971 non-null  float64
#  42  Closed forest, evergreen, broad leaf                      40971 non-null  float64
#  43  Closed forest, deciduous broad leaf                       40971 non-null  float64
#  44  Closed forest, unknown                                    40971 non-null  float64
#  45  Open forest, evergreen broad leaf                         40971 non-null  float64
#  46  Open forest, deciduous broad leaf                         40971 non-null  float64
#  47  Open forest, unknown definitions                          40971 non-null  float64
#  48  Open sea                                                  40971 non-null  float64
# dtypes: float64(44), int64(3), object(2)
# memory usage: 15.6+ MB

# %%
merged.to_csv('../wildfire_prediction/data/merged_file.csv')

# %%
merged.isna().sum()
# Out:
# Date_x                                                          0
# Region                                                          0
# count()[unit: km^2]                                             0
# max() Precipitation                                             7
# max() RelativeHumidity                                         42
# max() SoilWaterContent                                          0
# max() SolarRadiation                                           14
# max() Temperature                                              14
# max() WindSpeed                                                28
# mean() Precipitation                                            7
# mean() RelativeHumidity                                        42
# mean() SoilWaterContent                                         0
# mean() SolarRadiation                                          14
# mean() Temperature                                             14
# mean() WindSpeed                                               28
# min() Precipitation                                             7
# min() RelativeHumidity                                         42
# min() SoilWaterContent                                          0
# min() SolarRadiation                                           14
# min() Temperature                                              14
# min() WindSpeed                                                28
# variance() Precipitation                                        7
# variance() RelativeHumidity                                    42
# variance() SoilWaterContent                                     0
# variance() SolarRadiation                                      14
# variance() Temperature                                         14
# variance() WindSpeed                                           28
# Year                                                            0
# Month                                                           0
# Day                                                             0
# Estimated_fire_area                                         14304
# Mean_estimated_fire_brightness                              14304
# Mean_estimated_fire_radiative_power                         14304
# Vegetation_index_mean                                          63
# Vegetation_index_variance                                      63
# Shrubs                                                          0
# Herbaceous vegetation                                           0
# Cultivated and managed vegetation/agriculture (cropland)        0
# Urban / built up                                                0
# Bare / sparse vegetation                                        0
# Permanent water bodies                                          0
# Herbaceous wetland                                              0
# Closed forest, evergreen, broad leaf                            0
# Closed forest, deciduous broad leaf                             0
# Closed forest, unknown                                          0
# Open forest, evergreen broad leaf                               0
# Open forest, deciduous broad leaf                               0
# Open forest, unknown definitions                                0
# Open sea                                                        0
# dtype: int64

# %%
14000/len(merged)
# Out:
# 0.3417051084913719

# %%
merged[40908:]
# Out:
#            Date_x Region  count()[unit: km^2]  max() Precipitation  \
# 40908  2021-01-01    NSW         8.002343e+05            40.297012
# 40909  2021-01-01     NT         1.357561e+06            79.576355
# 40910  2021-01-01     QL         1.730605e+06           169.318497
# 40911  2021-01-01     SA         9.913151e+05            21.289888
# 40912  2021-01-01     TA         6.778526e+04             6.045939
# ...           ...    ...                  ...                  ...
# 40966  2021-01-09     QL         1.730605e+06            76.539787
# 40967  2021-01-09     SA         9.913151e+05             0.011193
# 40968  2021-01-09     TA         6.778526e+04             0.671226
# 40969  2021-01-09     VI         2.294532e+05             0.056003
# 40970  2021-01-09     WA         2.528546e+06             3.487231
#
#        max() RelativeHumidity  max() SoilWaterContent  max() SolarRadiation  \
# 40908               97.915169                0.477605             29.703640
# 40909               90.827301                0.496684             32.386189
# 40910               95.571617                0.504384             30.593243
# 40911               90.736847                0.320672             31.960894
# 40912               85.561798                0.369965             28.550343
# ...                       ...                     ...                   ...
# 40966               99.068840                0.491771             31.479033
# 40967               87.400673                0.291472             32.616680
# 40968               85.533943                0.335788             33.143166
# 40969               86.733360                0.411591             32.725616
# 40970               84.094559                0.374027             32.355438
#
#        max() Temperature  max() WindSpeed  mean() Precipitation  ...  \
# 40908          32.139332         6.103386              4.085987  ...
# 40909          35.408566         9.663922              2.727267  ...
# 40910          34.735016         9.124945              7.057093  ...
# 40911          35.179836         8.261878              0.287602  ...
# 40912          18.356850        12.458570              0.405518  ...
# ...                  ...              ...                   ...  ...
# 40966          32.235790        12.415317              4.161668  ...
# 40967          31.718039         6.366586              0.000055  ...
# 40968          18.692577         8.090628              0.020243  ...
# 40969          29.507277         5.823341              0.001011  ...
# 40970          36.807751         9.305047              0.024427  ...
#
#        Bare / sparse vegetation  Permanent water bodies  Herbaceous wetland  \
# 40908                       0.2                     0.2                 0.1
# 40909                       0.4                     0.1                 0.1
# 40910                       1.1                     0.1                 0.0
# 40911                       4.8                     1.2                 0.1
# 40912                       0.1                     1.9                 1.4
# ...                         ...                     ...                 ...
# 40966                       1.1                     0.1                 0.0
# 40967                       4.8                     1.2                 0.1
# 40968                       0.1                     1.9                 1.4
# 40969                       0.1                     0.6                 0.3
# 40970                       1.0                     0.4                 0.0
#
#        Closed forest, evergreen, broad leaf  \
# 40908                                  14.7
# 40909                                   1.0
# 40910                                   5.3
# 40911                                   0.3
# 40912                                  50.1
# ...                                     ...
# 40966                                   5.3
# 40967                                   0.3
# 40968                                  50.1
# 40969                                  23.9
# 40970                                   1.2
#
#        Closed forest, deciduous broad leaf  Closed forest, unknown  \
# 40908                                  6.8                     0.3
# 40909                                  7.7                     0.1
# 40910                                 13.3                     0.3
# 40911                                  1.3                     0.1
# 40912                                  0.6                     1.1
# ...                                    ...                     ...
# 40966                                 13.3                     0.3
# 40967                                  1.3                     0.1
# 40968                                  0.6                     1.1
# 40969                                  3.8                     0.3
# 40970                                  2.4                     0.2
#
#        Open forest, evergreen broad leaf  Open forest, deciduous broad leaf  \
# 40908                                0.5                                3.7
# 40909                                0.1                               13.6
# 40910                                0.1                               12.0
# 40911                                0.1                                1.4
# 40912                                7.2                                1.5
# ...                                  ...                                ...
# 40966                                0.1                               12.0
# 40967                                0.1                                1.4
# 40968                                7.2                                1.5
# 40969                                1.5                                2.7
# 40970                                0.1                                4.8
#
#        Open forest, unknown definitions  Open sea
# 40908                              10.3       0.1
# 40909                               9.3       0.5
# 40910                              11.0       0.3
# 40911                               5.3       0.6
# 40912                               7.2       3.0
# ...                                 ...       ...
# 40966                              11.0       0.3
# 40967                               5.3       0.6
# 40968                               7.2       3.0
# 40969                               5.2       0.9
# 40970                               8.7       0.8
#
# [63 rows x 49 columns]

# %%
merged[40908:].isna().sum()
# Out:
# Date_x                                                       0
# Region                                                       0
# count()[unit: km^2]                                          0
# max() Precipitation                                          0
# max() RelativeHumidity                                       0
# max() SoilWaterContent                                       0
# max() SolarRadiation                                         0
# max() Temperature                                            0
# max() WindSpeed                                              0
# mean() Precipitation                                         0
# mean() RelativeHumidity                                      0
# mean() SoilWaterContent                                      0
# mean() SolarRadiation                                        0
# mean() Temperature                                           0
# mean() WindSpeed                                             0
# min() Precipitation                                          0
# min() RelativeHumidity                                       0
# min() SoilWaterContent                                       0
# min() SolarRadiation                                         0
# min() Temperature                                            0
# min() WindSpeed                                              0
# variance() Precipitation                                     0
# variance() RelativeHumidity                                  0
# variance() SoilWaterContent                                  0
# variance() SolarRadiation                                    0
# variance() Temperature                                       0
# variance() WindSpeed                                         0
# Year                                                         0
# Month                                                        0
# Day                                                          0
# Estimated_fire_area                                         41
# Mean_estimated_fire_brightness                              41
# Mean_estimated_fire_radiative_power                         41
# Vegetation_index_mean                                       63
# Vegetation_index_variance                                   63
# Shrubs                                                       0
# Herbaceous vegetation                                        0
# Cultivated and managed vegetation/agriculture (cropland)     0
# Urban / built up                                             0
# Bare / sparse vegetation                                     0
# Permanent water bodies                                       0
# Herbaceous wetland                                           0
# Closed forest, evergreen, broad leaf                         0
# Closed forest, deciduous broad leaf                          0
# Closed forest, unknown                                       0
# Open forest, evergreen broad leaf                            0
# Open forest, deciduous broad leaf                            0
# Open forest, unknown definitions                             0
# Open sea                                                     0
# dtype: int64
