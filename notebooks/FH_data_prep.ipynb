# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/felixhermes/code/miguelferreira13/wildfire_prediction/wildfire_prediction/data/merged_file.csv')
data.head()
# Out:
#    Unnamed: 0      Date_x Region  count()[unit: km^2]  max() Precipitation  \
# 0           0  2005-01-01    NSW         8.002343e+05             1.836935
# 1           1  2005-01-01     NT         1.357561e+06           315.266815
# 2           2  2005-01-01     QL         1.730605e+06            74.452164
# 3           3  2005-01-01     SA         9.913151e+05             3.193624
# 4           4  2005-01-01     TA         6.778526e+04            13.604791
#
#    max() RelativeHumidity  max() SoilWaterContent  max() SolarRadiation  \
# 0               80.522964                0.414305             32.169781
# 1               95.683342                0.496140             31.634459
# 2               95.898270                0.472416             31.982830
# 3               81.980751                0.263911             31.734528
# 4               81.501442                0.368189             33.225517
#
#    max() Temperature  max() WindSpeed  ...  Bare / sparse vegetation  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40971 entries, 0 to 40970
# Data columns (total 50 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Unnamed: 0                                                40971 non-null  int64
#  1   Date_x                                                    40971 non-null  object
#  2   Region                                                    40971 non-null  object
#  3   count()[unit: km^2]                                       40971 non-null  float64
#  4   max() Precipitation                                       40964 non-null  float64
#  5   max() RelativeHumidity                                    40929 non-null  float64
#  6   max() SoilWaterContent                                    40971 non-null  float64
#  7   max() SolarRadiation                                      40957 non-null  float64
# ...

# %%
data.drop(columns = ['Unnamed: 0', 'Date_x', 'Mean_estimated_fire_brightness', 'Mean_estimated_fire_radiative_power'], inplace = True)

# %%
data['Estimated_fire_area']
# Out:
# 0              NaN
# 1         4.945000
# 2        38.831579
# 3              NaN
# 4              NaN
#            ...
# 40966          NaN
# 40967          NaN
# 40968     1.430000
# 40969          NaN
# 40970     9.000000
# Name: Estimated_fire_area, Length: 40971, dtype: float64

# %%
data['Estimated_fire_area'] = data['Estimated_fire_area'].fillna(0)

# %%
data['Estimated_fire_area']
# Out:
# 0         0.000000
# 1         4.945000
# 2        38.831579
# 3         0.000000
# 4         0.000000
#            ...
# 40966     0.000000
# 40967     0.000000
# 40968     1.430000
# 40969     0.000000
# 40970     9.000000
# Name: Estimated_fire_area, Length: 40971, dtype: float64

# %%
data['target'] = (data['Estimated_fire_area'] > 0).astype(int)

# %%
data['target'].unique()
# Out:
# array([0, 1])

# %%
data.head()
# Out:
#   Region  count()[unit: km^2]  max() Precipitation  max() RelativeHumidity  \
# 0    NSW         8.002343e+05             1.836935               80.522964
# 1     NT         1.357561e+06           315.266815               95.683342
# 2     QL         1.730605e+06            74.452164               95.898270
# 3     SA         9.913151e+05             3.193624               81.980751
# 4     TA         6.778526e+04            13.604791               81.501442
#
#    max() SoilWaterContent  max() SolarRadiation  max() Temperature  \
# 0                0.414305             32.169781          35.878704
# 1                0.496140             31.634459          38.136787
# 2                0.472416             31.982830          37.047943
# 3                0.263911             31.734528          38.326847
# 4                0.368189             33.225517          16.228510
#
#    max() WindSpeed  mean() Precipitation  mean() RelativeHumidity  ...  \
# ...

# %%
data['split'] = np.random.randn(data.shape[0], 1)

msk = np.random.rand(len(data)) <= 0.7

train = data[msk]
test = data[~msk]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28617 entries, 2 to 40970
# Data columns (total 48 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Region                                                    28617 non-null  object
#  1   count()[unit: km^2]                                       28617 non-null  float64
#  2   max() Precipitation                                       28611 non-null  float64
#  3   max() RelativeHumidity                                    28590 non-null  float64
#  4   max() SoilWaterContent                                    28617 non-null  float64
#  5   max() SolarRadiation                                      28609 non-null  float64
#  6   max() Temperature                                         28609 non-null  float64
#  7   max() WindSpeed                                           28600 non-null  float64
# ...

# %%
train.head()
# Out:
#    Region  count()[unit: km^2]  max() Precipitation  max() RelativeHumidity  \
# 2      QL         1.730605e+06            74.452164               95.898270
# 4      TA         6.778526e+04            13.604791               81.501442
# 5      VI         2.294532e+05             1.129023               80.269424
# 9      QL         1.730605e+06            87.775497               95.837463
# 10     SA         9.913151e+05             3.230288               84.714577
#
#     max() SoilWaterContent  max() SolarRadiation  max() Temperature  \
# 2                 0.472416             31.982830          37.047943
# 4                 0.368189             33.225517          16.228510
# 5                 0.389527             30.274399          25.299295
# 9                 0.477548             31.729107          35.675449
# 10                0.263650             32.662922          35.849258
#
#     max() WindSpeed  mean() Precipitation  mean() RelativeHumidity  ...  \
# ...

# %%
train.to_csv('/Users/felixhermes/code/miguelferreira13/wildfire_prediction/wildfire_prediction/data/FH_train.csv')
test.to_csv('/Users/felixhermes/code/miguelferreira13/wildfire_prediction/wildfire_prediction/data/FH_test.csv')
data.to_csv('/Users/felixhermes/code/miguelferreira13/wildfire_prediction/wildfire_prediction/data/FH_data.csv')
